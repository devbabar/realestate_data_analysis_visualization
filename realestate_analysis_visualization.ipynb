# %% [markdown]
# # Read data and plot graph

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
import seaborn as sns

# %%
# %matplotlib inline

# %%
df=pd.read_csv('RealEstate.csv')

# %%
df
# Out:
#         MLS             Location      Price  Bedrooms  Bathrooms  Size  \
# 0    132842        Arroyo Grande   795000.0         3          3  2371
# 1    134364          Paso Robles   399000.0         4          3  2818
# 2    135141          Paso Robles   545000.0         4          3  3032
# 3    135712            Morro Bay   909000.0         4          4  3540
# 4    136282   Santa Maria-Orcutt   109900.0         3          1  1249
# 5    136431               Oceano   324900.0         3          3  1800
# 6    137036   Santa Maria-Orcutt   192900.0         4          2  1603
# 7    137090   Santa Maria-Orcutt   215000.0         3          2  1450
# 8    137159            Morro Bay   999000.0         4          3  3360
# 9    137570           Atascadero   319000.0         3          2  1323
# 10   138053   Santa Maria-Orcutt   350000.0         3          2  1750
# 11   138730   Santa Maria-Orcutt   249000.0         3          2  1400
# ...

# %%
# Only display the houses in San Luis Obispo, bedroom and Price
san_luis_obispo = df[df['Location']=='San Luis Obispo'][['Bedrooms','Price/SQ.Ft']]

# %%
san_luis_obispo
# Out:
#      Bedrooms  Price/SQ.Ft
# 19          3       288.72
# 80          4       258.59
# 88          3       281.06
# 108         2       277.18
# 138         2       272.12
# 171         3       461.36
# 236         2       263.87
# 379         3       256.19
# 389         2       333.71
# 404         3       274.58
# 447         2       201.51
# 543         3       318.89
# 594         3       250.57
# 778         3       336.96

# %%
x = san_luis_obispo['Price/SQ.Ft']
x
# Out:
# 19     288.72
# 80     258.59
# 88     281.06
# 108    277.18
# 138    272.12
# 171    461.36
# 236    263.87
# 379    256.19
# 389    333.71
# 404    274.58
# 447    201.51
# 543    318.89
# 594    250.57
# 778    336.96
# Name: Price/SQ.Ft, dtype: float64

# %%
y = san_luis_obispo['Bedrooms']
y
# Out:
# 19     3
# 80     4
# 88     3
# 108    2
# 138    2
# 171    3
# 236    2
# 379    3
# 389    2
# 404    3
# 447    2
# 543    3
# 594    3
# 778    3
# Name: Bedrooms, dtype: int64

# %%
# fig,axes = plt.subplots(figsize=(12,6))
a =san_luis_obispo.plot(kind='bar',figsize=(12,6))

# %%
# x=df['Location']
# y=df['Status']
# sns.lmplot('x','y',data=df,fit_reg=False)
sns.countplot(x='Status',data=df)

# %%
fig,axes=plt.subplots(figsize=(18,8))

df.groupby('Location').count()['Status'].plot()

# %%
fig,axes=plt.subplots(figsize=(18,10))
sns.countplot(data=df, x='Bedrooms', hue='Bathrooms')
